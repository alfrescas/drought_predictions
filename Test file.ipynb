# %%
import pandas as pd

# %%
df_2010= pd.read_excel("usco2010.xlsx")
# Out:
# C:\Users\thana\anaconda3\envs\PythonData\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df_2010.head()
# Out:
#   STATE  STATEFIPS          COUNTY  COUNTYFIPS  FIPS  YEAR  TP-TotPop  \
# 0    AL          1  Autauga County           1  1001  2010     54.571
# 1    AL          1  Baldwin County           3  1003  2010    182.265
# 2    AL          1  Barbour County           5  1005  2010     27.457
# 3    AL          1     Bibb County           7  1007  2010     22.915
# 4    AL          1   Blount County           9  1009  2010     57.322
#
#    PS-GWPop  PS-SWPop  PS-TOPop  ...  PC-Power  TO-WGWFr  TO-WGWSa  TO-WGWTo  \
# 0       NaN       NaN    48.222  ...   6738.26     18.38       0.0     18.38
# 1       NaN       NaN   153.463  ...      0.00     57.35       0.0     57.35
# 2       NaN       NaN    25.555  ...      0.00      6.71       0.0      6.71
# 3       NaN       NaN    21.279  ...      0.00      6.06       0.0      6.06
# 4       NaN       NaN    44.464  ...      0.00      4.04       0.0      4.04
#
#    TO-WSWFr  TO-WSWSa  TO-WSWTo  TO-WFrTo  TO-WSaTo  TO-WTotl
# 0     37.17       0.0     37.17     55.55       0.0     55.55
# 1      7.01       0.0      7.01     64.36       0.0     64.36
# 2      4.34       0.0      4.34     11.05       0.0     11.05
# 3      1.55       0.0      1.55      7.61       0.0      7.61
# 4     53.04       0.0     53.04     57.08       0.0     57.08
#
# [5 rows x 117 columns]

# %%
df_2010.dtypes
# Out:
# STATE          object
# STATEFIPS       int64
# COUNTY         object
# COUNTYFIPS      int64
# FIPS            int64
#                ...
# TO-WSWSa      float64
# TO-WSWTo      float64
# TO-WFrTo      float64
# TO-WSaTo      float64
# TO-WTotl      float64
# Length: 117, dtype: object

# %%
columnslist = df.columns.values.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10804\4218490510.py in <module>
# ----> 1 columnslist = df.columns.values.tolist()
#
# NameError: name 'df' is not defined

# %%
columnslist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10804\409321598.py in <module>
# ----> 1 columnslist
#
# NameError: name 'columnslist' is not defined

# %%
State_val = ['WY', 'UT', 'NM', 'CO']

# %%
test_df = pd.DataFrame()

# %%
for val in State_val:
    test_df=test_df.append(df_2010.loc[df_2010['STATE'] == (val)])

# %%
test_df
# Out:
#      STATE  STATEFIPS             COUNTY  COUNTYFIPS   FIPS  YEAR  TP-TotPop  \
# 3120    WY         56      Albany County           1  56001  2010     36.299
# 3121    WY         56    Big Horn County           3  56003  2010     11.668
# 3122    WY         56    Campbell County           5  56005  2010     46.133
# 3123    WY         56      Carbon County           7  56007  2010     15.885
# 3124    WY         56    Converse County           9  56009  2010     13.833
# ...    ...        ...                ...         ...    ...   ...        ...
# 303     CO          8      Summit County         117   8117  2010     27.994
# 304     CO          8      Teller County         119   8119  2010     23.350
# 305     CO          8  Washington County         121   8121  2010      4.814
# 306     CO          8        Weld County         123   8123  2010    252.825
# 307     CO          8        Yuma County         125   8125  2010     10.043
#
#       PS-GWPop  PS-SWPop  PS-TOPop  ...  PC-Power  TO-WGWFr  TO-WGWSa  \
# 3120    14.944    14.725    29.669  ...      0.00      4.36      0.08
# 3121     5.324     3.419     8.743  ...      0.00      4.09      5.55
# 3122    45.430     0.000    45.430  ...   2170.15     45.26     22.88
# 3123     7.822     5.563    13.385  ...      0.00      4.59      0.17
# 3124     8.342     0.360     8.702  ...   4707.33      9.19      1.96
# ...        ...       ...       ...  ...       ...       ...       ...
# 303     16.409     8.288    24.697  ...      0.00      2.99      0.00
# 304     12.129     3.326    15.455  ...      0.00      1.74      0.00
# 305      2.314     0.000     2.314  ...      0.00     58.57      1.19
# 306      9.824   241.194   251.018  ...   2434.68     20.32      0.53
# 307      6.191     0.000     6.191  ...      0.00    215.16      0.07
#
#       TO-WGWTo  TO-WSWFr  TO-WSWSa  TO-WSWTo  TO-WFrTo  TO-WSaTo  TO-WTotl
# 3120      4.44    184.86       0.0    184.86    189.22      0.08    189.30
# 3121      9.64    383.15       0.0    383.15    387.24      5.55    392.79
# 3122     68.14     53.28       0.0     53.28     98.54     22.88    121.42
# 3123      4.76    370.94       0.0    370.94    375.53      0.17    375.70
# 3124     11.15    144.94       0.0    144.94    154.13      1.96    156.09
# ...        ...       ...       ...       ...       ...       ...       ...
# 303       2.99     65.71       0.0     65.71     68.70      0.00     68.70
# 304       1.74      5.86       0.0      5.86      7.60      0.00      7.60
# 305      59.76     13.64       0.0     13.64     72.21      1.19     73.40
# 306      20.85    441.28       0.0    441.28    461.60      0.53    462.13
# 307     215.23      5.58       0.0      5.58    220.74      0.07    220.81
#
# [149 rows x 117 columns]
